# %% [markdown]
# # Pointers arithmetic
#
# Computer memory can be viewed as a linear arrangement of data storage and code. Each memory address points to a single byte and these memory addresses are represented by hexadecimal notation.

# %%
# !gcc definition_and_use_of_pointers -o main && ./main

# %% [markdown]
# ## Number of bytes occupied per data type
#
# The basic data types in C occupy different numbers of bytes.

# %%
# !gcc data_type_sizes.c -o main && ./main

# %% [markdown]
# > An displacement in bytes of a pointer depends on its data type.

# %% [markdown]
# ## Matrices viewed as vectors
#
# Matrices can be viewed as vectors using the following conversational formula:
#
# $$
# \text{matrix}_{(i,j)} = vector_{(\text{elements in a row} * i + j)}
# $$

# %%
# !gcc matrix_to_vector.c -o main && ./main
